# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import seaborn as sns

# %% [markdown]
# # Load data and make data frame

# %%
df = pd.read_csv("./genomes_fasta/genome_quality_report.tsv", sep="\t")
df.head()
# Out:
#           Name  Completeness  Contamination          Completeness_Model_Used  \
# 0  3045160_421         97.65           2.79   Gradient Boost (General Model)
# 1    2202732_9         97.17           4.17  Neural Network (Specific Model)
# 2    1714258_3         90.05           0.06  Neural Network (Specific Model)
# 3   2020860_61         99.92           1.06  Neural Network (Specific Model)
# 4      94694_5         99.45           0.14  Neural Network (Specific Model)
#
#    Translation_Table_Used  Coding_Density  Contig_N50  Average_Gene_Length  \
# 0                      11           0.899      125725           287.254945
# 1                      11           0.911       21715           239.937397
# 2                      11           0.853       98570           241.859750
# 3                      11           0.894      590720           275.321820
# 4                      11           0.892       26831           279.394387
#
#    Genome_Size  GC_Content  Total_Coding_Sequences  Additional_Notes
# 0      1740059        0.45                    1820               NaN
# 1      1435948        0.30                    1821               NaN
# 2      1760081        0.61                    2082               NaN
# 3      2180697        0.46                    2374               NaN
# 4      1268528        0.45                    1354               NaN

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Contamination vs. Compeletness

# %%
condition = (df["Contamination"] < 5) & (df["Completeness"] > 85)
df["meets_criteria"] = condition.map({True: "Yes", False: "No"})

# %%
plt.figure(figsize=(10, 6))
len_genomes = len(df)
len_meets_criteria_yes =  len(df[df["meets_criteria"] == "Yes"])
len_meets_criteria_no = len_genomes - len_meets_criteria_yes
plot = sns.scatterplot(
    data=df,
    x="Completeness",
    y="Contamination",
    hue="meets_criteria",
    style="meets_criteria",  
    palette={"Yes": "#DD8452", "No": "#4C72B0"}  

)
vline_x = 85
hline_y = 5
plt.axhline(y=hline_y, linestyle='--', color='gray', linewidth=1)
plt.axvline(x=vline_x, linestyle='--', color='gray', linewidth=1)
plt.xlabel("Completeness [%]")
plt.ylabel("Contamination [%]")
plt.ylim(-1, 8)

handles, labels = plot.get_legend_handles_labels()
vline_legend = Line2D([0], [0], color='gray', lw=1, linestyle='--', label=f'vline @ x={vline_x}')
hline_legend = Line2D([0], [0], color='gray', lw=1, linestyle='--', label=f'hline @ y={hline_y}')

handles.extend([vline_legend, hline_legend])
labels.extend([f"Vertical line at x = {vline_x}", f"Horizontal line at y = {hline_y}"])

plt.legend(
    handles=handles,       
    labels=[f"Meets Criteria (n={len_meets_criteria_yes})", f"Other (n={len_meets_criteria_no})", f"{vline_x} % Completeness threshold", f"{hline_y} % Contamination threshold"], 
    
    loc='upper right',          
    frameon=True               
)
plt.title(f"Genome Quality Assessment (n={len_genomes})")
plt.show()

# %% [markdown]
# # Extract tRNA number from BV-BRC

# %%
# import requests
# import json

# %%
# # Use API 
# n_trna = []
# for name in df["Name"]:
#     name = name.replace("_", ".")
#     result = requests.get(f"https://www.bv-brc.org/api/genome/{name}")
#     result_dict = json.loads(result.text)
#     n_trna.append(result_dict["trna"])

# %%
# # Add tRNA number to df
# df["n_trna"] = n_trna
# df
# Out:
#            Name  Completeness  Contamination          Completeness_Model_Used  \
# 0   3045160_421         97.65           2.79   Gradient Boost (General Model)
# 1     2202732_9         97.17           4.17  Neural Network (Specific Model)
# 2     1714258_3         90.05           0.06  Neural Network (Specific Model)
# 3    2020860_61         99.92           1.06  Neural Network (Specific Model)
# 4       94694_5         99.45           0.14  Neural Network (Specific Model)
# 5   2026714_364         87.52           2.10   Gradient Boost (General Model)
# 6     1132505_7         99.71           0.96  Neural Network (Specific Model)
# 7     555311_12        100.00           1.60  Neural Network (Specific Model)
# 8     2852089_5         92.98           0.23  Neural Network (Specific Model)
# 9     399549_24         99.98           0.70  Neural Network (Specific Model)
# 10   2599821_17         75.63           0.99   Gradient Boost (General Model)
# 11   2599821_28         89.62           0.28   Gradient Boost (General Model)
# 12   2026764_32         91.95           0.52   Gradient Boost (General Model)
# 13   2093792_57         92.96           0.01   Gradient Boost (General Model)
# 14  2250274_361         87.34           0.57   Gradient Boost (General Model)
# 15  2250274_376         88.94           0.27   Gradient Boost (General Model)
# 16   2026736_90         97.76           0.12   Gradient Boost (General Model)
# 17  2250274_771         70.23           0.54  Neural Network (Specific Model)
# 18    1803513_5         87.46           1.62   Gradient Boost (General Model)
# 19   2250274_89         83.04           0.65   Gradient Boost (General Model)
# 20  2026739_687         99.97           0.30  Neural Network (Specific Model)
# 21  2026739_333         87.26           2.73   Gradient Boost (General Model)
# 22    1765056_4         99.63           0.88  Neural Network (Specific Model)
# 23  2026739_544         93.94           2.31   Gradient Boost (General Model)
# 24  2026739_441         95.50           0.50  Neural Network (Specific Model)
# 25  2026739_744         90.66           0.27  Neural Network (Specific Model)
# 26    1635285_4         85.88           0.08  Neural Network (Specific Model)
# 27  2026739_361         90.68           1.00  Neural Network (Specific Model)
# 28  2026739_456         97.30           0.18  Neural Network (Specific Model)
# 29  2026739_986         92.31           0.42   Gradient Boost (General Model)
# 30   2053491_86         96.37           3.60   Gradient Boost (General Model)
# 31   2053489_56         97.72           3.68   Gradient Boost (General Model)
# 32    3061966_7         86.01           4.57   Gradient Boost (General Model)
# 33    3045163_7         86.00           0.00   Gradient Boost (General Model)
# 34  2053489_142         87.95           3.86   Gradient Boost (General Model)
# 35  2026747_195         93.92           0.41   Gradient Boost (General Model)
# 36  2026747_106         85.49           2.97   Gradient Boost (General Model)
# 37  2053489_225         94.79           1.79   Gradient Boost (General Model)
# 38  2026747_124         90.28           4.50   Gradient Boost (General Model)
# 39  2053489_161         97.87           2.49   Gradient Boost (General Model)
# 40   3061966_12         86.01           4.57   Gradient Boost (General Model)
#
#     Translation_Table_Used  Coding_Density  Contig_N50  Average_Gene_Length  \
# 0                       11           0.899      125725           287.254945
# 1                       11           0.911       21715           239.937397
# 2                       11           0.853       98570           241.859750
# 3                       11           0.894      590720           275.321820
# 4                       11           0.892       26831           279.394387
# 5                       11           0.914      187909           277.349757
# 6                       11           0.874     1776831           255.734542
# 7                       11           0.865       24718           248.703680
# 8                       11           0.896       17139           233.868966
# 9                       11           0.890     2190631           272.088676
# 10                      11           0.940        6204           248.797943
# 11                      11           0.925       11548           274.768498
# 12                      11           0.928       14692           250.385455
# 13                      11           0.935       15022           254.430029
# 14                      11           0.947       17309           264.326241
# 15                      11           0.946       11207           267.589552
# 16                      11           0.919       36798           271.704977
# 17                      11           0.901        6262           262.005643
# 18                      11           0.793        9064           268.705432
# 19                      11           0.882       11948           294.522866
# 20                      11           0.729      126496           291.107609
# 21                      11           0.911       19782           285.721834
# 22                      11           0.870     3047371           290.052305
# 23                      11           0.948       35975           342.274265
# 24                      11           0.773       80133           304.463997
# 25                      11           0.950       38047           283.966814
# 26                      11           0.911       57160           283.221423
# 27                      11           0.897       14117           299.517527
# 28                      11           0.832       15826           247.436474
# 29                      11           0.895       12757           273.825770
# 30                      11           0.891       37304           297.782387
# 31                      11           0.879      136887           324.246030
# 32                      11           0.883       12112           292.811472
# 33                      11           0.921       24088           254.011869
# 34                      11           0.873       15834           292.419576
# 35                      11           0.906      129183           316.847557
# 36                      11           0.914       13723           299.013403
# 37                      11           0.863       19793           299.841661
# 38                      11           0.886       13812           295.320011
# 39                      11           0.822       21229           291.074226
# 40                      11           0.883       12112           292.811472
#
#     Genome_Size  GC_Content  Total_Coding_Sequences  Additional_Notes  \
# 0       1740059        0.45                    1820               NaN
# 1       1435948        0.30                    1821               NaN
# 2       1760081        0.61                    2082               NaN
# 3       2180697        0.46                    2374               NaN
# 4       1268528        0.45                    1354               NaN
# 5       1308518        0.43                    1441               NaN
# 6       2694762        0.35                    3089               NaN
# 7       2680466        0.35                    3125               NaN
# 8       1359568        0.33                    1740               NaN
# 9       2190631        0.46                    2402               NaN
# 10      1078181        0.52                    1361               NaN
# 11      1585234        0.44                    1784               NaN
# 12       664916        0.30                     825               NaN
# 13       557628        0.46                     686               NaN
# 14       703505        0.50                     846               NaN
# 15       678943        0.43                     804               NaN
# 16       976286        0.44                    1105               NaN
# 17       771300        0.58                     886               NaN
# 18      1456468        0.33                    1436               NaN
# 19       655542        0.33                     656               NaN
# 20      4212843        0.40                    3522               NaN
# 21      2149721        0.68                    2290               NaN
# 22      4184591        0.62                    4187               NaN
# 23      1470536        0.38                    1360               NaN
# 24      3653553        0.46                    3097               NaN
# 25      1208994        0.70                    1356               NaN
# 26      1293648        0.56                    1391               NaN
# 27      1567955        0.54                    1569               NaN
# 28      2059236        0.35                    2314               NaN
# 29      1633162        0.61                    1785               NaN
# 30      2944246        0.45                    2941               NaN
# 31      3966622        0.35                    3589               NaN
# 32      4346456        0.31                    4376               NaN
# 33       834426        0.56                    1011               NaN
# 34      3219989        0.32                    3208               NaN
# 35      1607935        0.30                    1535               NaN
# 36      2266433        0.33                    2313               NaN
# 37      2954021        0.59                    2842               NaN
# 38      3621793        0.33                    3628               NaN
# 39      3361411        0.27                    3166               NaN
# 40      4346456        0.31                    4376               NaN
#
#    meets_criteria  n_trna
# 0             Yes      42
# 1             Yes      45
# 2             Yes      28
# 3             Yes      46
# 4             Yes      34
# 5             Yes      37
# 6             Yes      46
# 7             Yes      45
# 8             Yes      36
# 9             Yes      46
# 10             No      19
# 11            Yes      29
# 12            Yes      25
# 13            Yes      38
# 14            Yes      40
# 15            Yes      32
# 16            Yes      34
# 17             No      20
# 18            Yes      39
# 19             No      15
# 20            Yes      51
# 21            Yes      42
# 22            Yes      48
# 23            Yes      37
# 24            Yes      51
# 25            Yes      26
# 26            Yes      39
# 27            Yes      39
# 28            Yes      33
# 29            Yes      37
# 30            Yes      46
# 31            Yes      21
# 32            Yes      25
# 33            Yes      43
# 34            Yes      32
# 35            Yes      36
# 36            Yes      37
# 37            Yes      32
# 38            Yes      37
# 39            Yes      56
# 40            Yes      25

# %%
# # Save result to csv
# df.to_csv("./genomes_fasta/genome_quality_report_result.csv", index=False)

# %% [markdown]
# ## Plot Genome size vs. Number of tRNAs

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("./genomes_fasta/genome_quality_report_result.csv")
df
# Out:
#            Name  Completeness  Contamination          Completeness_Model_Used  \
# 0   3045160_421         97.65           2.79   Gradient Boost (General Model)
# 1     2202732_9         97.17           4.17  Neural Network (Specific Model)
# 2     1714258_3         90.05           0.06  Neural Network (Specific Model)
# 3    2020860_61         99.92           1.06  Neural Network (Specific Model)
# 4       94694_5         99.45           0.14  Neural Network (Specific Model)
# 5   2026714_364         87.52           2.10   Gradient Boost (General Model)
# 6     1132505_7         99.71           0.96  Neural Network (Specific Model)
# 7     555311_12        100.00           1.60  Neural Network (Specific Model)
# 8     2852089_5         92.98           0.23  Neural Network (Specific Model)
# 9     399549_24         99.98           0.70  Neural Network (Specific Model)
# 10   2599821_17         75.63           0.99   Gradient Boost (General Model)
# 11   2599821_28         89.62           0.28   Gradient Boost (General Model)
# 12   2026764_32         91.95           0.52   Gradient Boost (General Model)
# 13   2093792_57         92.96           0.01   Gradient Boost (General Model)
# 14  2250274_361         87.34           0.57   Gradient Boost (General Model)
# 15  2250274_376         88.94           0.27   Gradient Boost (General Model)
# 16   2026736_90         97.76           0.12   Gradient Boost (General Model)
# 17  2250274_771         70.23           0.54  Neural Network (Specific Model)
# 18    1803513_5         87.46           1.62   Gradient Boost (General Model)
# 19   2250274_89         83.04           0.65   Gradient Boost (General Model)
# 20  2026739_687         99.97           0.30  Neural Network (Specific Model)
# 21  2026739_333         87.26           2.73   Gradient Boost (General Model)
# 22    1765056_4         99.63           0.88  Neural Network (Specific Model)
# 23  2026739_544         93.94           2.31   Gradient Boost (General Model)
# 24  2026739_441         95.50           0.50  Neural Network (Specific Model)
# 25  2026739_744         90.66           0.27  Neural Network (Specific Model)
# 26    1635285_4         85.88           0.08  Neural Network (Specific Model)
# 27  2026739_361         90.68           1.00  Neural Network (Specific Model)
# 28  2026739_456         97.30           0.18  Neural Network (Specific Model)
# 29  2026739_986         92.31           0.42   Gradient Boost (General Model)
# 30   2053491_86         96.37           3.60   Gradient Boost (General Model)
# 31   2053489_56         97.72           3.68   Gradient Boost (General Model)
# 32    3061966_7         86.01           4.57   Gradient Boost (General Model)
# 33    3045163_7         86.00           0.00   Gradient Boost (General Model)
# 34  2053489_142         87.95           3.86   Gradient Boost (General Model)
# 35  2026747_195         93.92           0.41   Gradient Boost (General Model)
# 36  2026747_106         85.49           2.97   Gradient Boost (General Model)
# 37  2053489_225         94.79           1.79   Gradient Boost (General Model)
# 38  2026747_124         90.28           4.50   Gradient Boost (General Model)
# 39  2053489_161         97.87           2.49   Gradient Boost (General Model)
# 40   3061966_12         86.01           4.57   Gradient Boost (General Model)
#
#     Translation_Table_Used  Coding_Density  Contig_N50  Average_Gene_Length  \
# 0                       11           0.899      125725           287.254945
# 1                       11           0.911       21715           239.937397
# 2                       11           0.853       98570           241.859750
# 3                       11           0.894      590720           275.321820
# 4                       11           0.892       26831           279.394387
# 5                       11           0.914      187909           277.349757
# 6                       11           0.874     1776831           255.734542
# 7                       11           0.865       24718           248.703680
# 8                       11           0.896       17139           233.868966
# 9                       11           0.890     2190631           272.088676
# 10                      11           0.940        6204           248.797943
# 11                      11           0.925       11548           274.768498
# 12                      11           0.928       14692           250.385455
# 13                      11           0.935       15022           254.430029
# 14                      11           0.947       17309           264.326241
# 15                      11           0.946       11207           267.589552
# 16                      11           0.919       36798           271.704977
# 17                      11           0.901        6262           262.005643
# 18                      11           0.793        9064           268.705432
# 19                      11           0.882       11948           294.522866
# 20                      11           0.729      126496           291.107609
# 21                      11           0.911       19782           285.721834
# 22                      11           0.870     3047371           290.052305
# 23                      11           0.948       35975           342.274265
# 24                      11           0.773       80133           304.463997
# 25                      11           0.950       38047           283.966814
# 26                      11           0.911       57160           283.221423
# 27                      11           0.897       14117           299.517527
# 28                      11           0.832       15826           247.436474
# 29                      11           0.895       12757           273.825770
# 30                      11           0.891       37304           297.782387
# 31                      11           0.879      136887           324.246030
# 32                      11           0.883       12112           292.811472
# 33                      11           0.921       24088           254.011869
# 34                      11           0.873       15834           292.419576
# 35                      11           0.906      129183           316.847557
# 36                      11           0.914       13723           299.013403
# 37                      11           0.863       19793           299.841661
# 38                      11           0.886       13812           295.320011
# 39                      11           0.822       21229           291.074226
# 40                      11           0.883       12112           292.811472
#
#     Genome_Size  GC_Content  Total_Coding_Sequences  Additional_Notes  \
# 0       1740059        0.45                    1820               NaN
# 1       1435948        0.30                    1821               NaN
# 2       1760081        0.61                    2082               NaN
# 3       2180697        0.46                    2374               NaN
# 4       1268528        0.45                    1354               NaN
# 5       1308518        0.43                    1441               NaN
# 6       2694762        0.35                    3089               NaN
# 7       2680466        0.35                    3125               NaN
# 8       1359568        0.33                    1740               NaN
# 9       2190631        0.46                    2402               NaN
# 10      1078181        0.52                    1361               NaN
# 11      1585234        0.44                    1784               NaN
# 12       664916        0.30                     825               NaN
# 13       557628        0.46                     686               NaN
# 14       703505        0.50                     846               NaN
# 15       678943        0.43                     804               NaN
# 16       976286        0.44                    1105               NaN
# 17       771300        0.58                     886               NaN
# 18      1456468        0.33                    1436               NaN
# 19       655542        0.33                     656               NaN
# 20      4212843        0.40                    3522               NaN
# 21      2149721        0.68                    2290               NaN
# 22      4184591        0.62                    4187               NaN
# 23      1470536        0.38                    1360               NaN
# 24      3653553        0.46                    3097               NaN
# 25      1208994        0.70                    1356               NaN
# 26      1293648        0.56                    1391               NaN
# 27      1567955        0.54                    1569               NaN
# 28      2059236        0.35                    2314               NaN
# 29      1633162        0.61                    1785               NaN
# 30      2944246        0.45                    2941               NaN
# 31      3966622        0.35                    3589               NaN
# 32      4346456        0.31                    4376               NaN
# 33       834426        0.56                    1011               NaN
# 34      3219989        0.32                    3208               NaN
# 35      1607935        0.30                    1535               NaN
# 36      2266433        0.33                    2313               NaN
# 37      2954021        0.59                    2842               NaN
# 38      3621793        0.33                    3628               NaN
# 39      3361411        0.27                    3166               NaN
# 40      4346456        0.31                    4376               NaN
#
#    meets_criteria  n_trna
# 0             Yes      42
# 1             Yes      45
# 2             Yes      28
# 3             Yes      46
# 4             Yes      34
# 5             Yes      37
# 6             Yes      46
# 7             Yes      45
# 8             Yes      36
# 9             Yes      46
# 10             No      19
# 11            Yes      29
# 12            Yes      25
# 13            Yes      38
# 14            Yes      40
# 15            Yes      32
# 16            Yes      34
# 17             No      20
# 18            Yes      39
# 19             No      15
# 20            Yes      51
# 21            Yes      42
# 22            Yes      48
# 23            Yes      37
# 24            Yes      51
# 25            Yes      26
# 26            Yes      39
# 27            Yes      39
# 28            Yes      33
# 29            Yes      37
# 30            Yes      46
# 31            Yes      21
# 32            Yes      25
# 33            Yes      43
# 34            Yes      32
# 35            Yes      36
# 36            Yes      37
# 37            Yes      32
# 38            Yes      37
# 39            Yes      56
# 40            Yes      25

# %%
y_trna=df["n_trna"].values
x_genome_size=df["Genome_Size"].values
fig, ax = plt.subplots(figsize = (9, 6))


X = x_genome_size.reshape(-1, 1)
y = y_trna

scatter_color = "#2a9d8f"  
line_color = "#e76f51"     

lin_reg = LinearRegression()
lin_reg.fit(X, y)
y_pred_linear = lin_reg.predict(X)
r2_linear = r2_score(y, y_pred_linear)

sns.scatterplot(x=df["Genome_Size"], y=df["n_trna"], color=scatter_color, label='tRNA Genes', s=60, edgecolor='w')
sns.lineplot(x=x_genome_size, y=y_pred_linear, color=line_color, label=f'Linear Fit (R² = {r2_linear:.2f})')

ax.set_ylabel("Number of tRNA genes per genome")
ax.set_xlabel("Genome size")
ax.set_xscale("log")
# ax.set_yscale("log")

# %% [markdown]
# ## Plot Number of protein-coding sequences per genome vs. Number of tRNAs

# %%
y_trna=df["n_trna"].values
x_genome_n_genes=df["Total_Coding_Sequences"].values
fig, ax = plt.subplots(figsize = (9, 6))

# Reshape x_genome_size to be 2D: (n_samples, 1)
X = x_genome_n_genes.reshape(-1, 1)
y = y_trna

scatter_color = "#2a9d8f"  
line_color = "#e76f51"     

lin_reg = LinearRegression()
lin_reg.fit(X, y)
y_pred_linear = lin_reg.predict(X)
r2_linear = r2_score(y, y_pred_linear)

sns.scatterplot(x=df["Total_Coding_Sequences"], y=df["n_trna"], color=scatter_color, label='tRNA Genes', s=60, edgecolor='w')
sns.lineplot(x=x_genome_n_genes, y=y_pred_linear, color=line_color, label=f'Linear Fit (R² = {r2_linear:.2f})')

ax.set_ylabel("Number of tRNA genes per genome")
ax.set_xlabel("Total gene number")
# ax.set_xscale("log")
# ax.set_yscale("log")
# Out:
# Text(0.5, 0, 'Total gene number')
